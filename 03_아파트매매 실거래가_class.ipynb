# %% [markdown]
# # OpenAPI 활용
#  * 공공데이터 포털 : https://www.data.go.kr/
#  * 회원가입
#  * '아파트매매 실거래자료'검색
#  * OPEN API에서 XML 형태로 제공하는 항목 선택
#  * 활용 신청 > 기타
#
#  * 마이페이지 > 일반 인증키(UTF-8), End Point, hwp 문서 확인

# %%
import json
import xmltodict
import csv
import requests

# %%
def wirte_csv(file_name, data) :
    ## encoding='utf-8' 시 한글 깨짐 현상 발견시, 
    # encoding='euc-kr'로 해야 안깨짐, 
    # 이유 크롤하는 사이트가 euc-kr 인코딩된 한글 바이트를 사용하였기 때문,
    ## 파이썬 출력결과는 기본적으로 utf-8, euc-kr 인코딩이 되지만, csv 파일 저장시 인코딩 방식을 직접 저장해줘야 함
    with open(f'{file_name}.csv', 'a', encoding='euc-kr') as f:
        writer = csv.writer(f, lineterminator='\n')
        writer.writerow(data)

# %%
### https://www.data.go.kr/iim/api/selectAPIAcountView.do 
# 지역코드
LAWD_CD = 11110
# 계약월 6자리
DEAL_YMD = 201812
# 인증키
API_KEY = '일반 인증키(UTF-8)'
url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?LAWD_CD={LAWD_CD}&DEAL_YMD={DEAL_YMD}&serviceKey={API_KEY}'

# get html
response = requests.get(url)

jsonString = json.dumps(xmltodict.parse(response.text), indent=4, ensure_ascii=False)
# print(jsonString)
jsonDict = json.loads(jsonString)

item = jsonDict['response']['body']['items']['item']
wirte_csv('2_부동산_정보', ["거래금액", "아파트명", "전용면적"])
for each in item :
    if float(each['전용면적']) > 80 :
        print("[거래금액]" + each['거래금액'] + " [아파트명] " + each['아파트'] + " [전용면적]" +  each['전용면적'])
        wirte_csv('2_부동산_정보', [each['거래금액'], each['아파트'], each['전용면적']])
# Out:
# {
#     "response": {
#         "header": {
#             "resultCode": "00",
#             "resultMsg": "NORMAL SERVICE."
#         },
#         "body": {
#             "items": {
#                 "item": [
#                     {
#                         "거래금액": "23,500",
#                         "건축년도": "2003",
#                         "년": "2018",
#                         "도로명": "돈화문로11가길",
#                         "도로명건물본번호코드": "00059",
#                         "도로명건물부번호코드": "00000",
#                         "도로명시군구코드": "11110",
#                         "도로명일련번호코드": "03",
#                         "도로명지상지하코드": "0",
#                         "도로명코드": "4100050",
#                         "법정동": "익선동",
#                         "법정동본번코드": "0055",
#                         "법정동부번코드": "0000",
#                         "법정동시군구코드": "11110",
#                         "법정동읍면동코드": "13300",
#                         "법정동지번코드": "1",
#                         "아파트": "현대뜨레비앙",
#                         "월": "12",
#                         "일": "8",
#                         "일련번호": "11110-102",
#                         "전용면적": "36.08",
#                         "지번": "55",
#                         "지역코드": "11110",
#                         "층": "7"
#                     },
#                     {
#                         "거래금액": "20,000",
#                         "건축년도": "2014",
#                         "년": "2018",
#                         "도로명": "대학로",
#                         "도로명건물본번호코드": "00047",
#                         "도로명건물부번호코드": "00000",
#                         "도로명시군구코드": "11110",
#                         "도로명일련번호코드": "05",
#                         "도로명지상지하코드": "0",
#                         "도로명코드": "3100002",
#                         "법정동": "연건동",
#                         "법정동본번코드": "0195",
#                         "법정동부번코드": "0010",
#                         "법정동시군구코드": "11110",
#                         "법정동읍면동코드": "16600",
#                         "법정동지번코드": "1",
#                         "아파트": "이화에수풀",
#                         "월": "12",
#                         "일": "18",
#                         "일련번호": "11110-2359",
#                         "전용면적": "16.98",
#                         "지번": "195-10",
#                         "지역코드": "11110",
#                         "층": "7"
#                     },
#                     {
#                         "거래금액": "45,500",
#                         "건축년도": "2004",
#                         "년": "2018",
#                         "도로명": "혜화로8길",
#                         "도로명건물본번호코드": "00025",
#                         "도로명건물부번호코드": "00000",
#                         "도로명시군구코드": "11110",
#                         "도로명일련번호코드": "01",
#                         "도로명지상지하코드": "0",
#                         "도로명코드": "4100549",
#                         "법정동": "혜화동",
#                         "법정동본번코드": "0020",
#                         "법정동부번코드": "0012",
#                         "법정동시군구코드": "11110",
#                         "법정동읍면동코드": "16900",
#                         "법정동지번코드": "1",
#                         "아파트": "혜화훼미리",
#                         "월": "12",
#                         "일": "3",
#                         "일련번호": "11110-206",
#                         "전용면적": "60.82",
#                         "지번": "20-12",
#                         "지역코드": "11110",
#                         "층": "7"
#                     },
#                     {
#                         "거래금액": "26,800",
#                         "건축년도": "2002",
#                         "년": "2018",
#                         "도로명": "창신길",
#                         "도로명건물본번호코드": "00140",
#                         "도로명건물부번호코드": "00014",
#                         "도로명시군구코드": "11110",
#                         "도로명일련번호코드": "01",
#                         "도로명지상지하코드": "0",
#                         "도로명코드": "4100453",
#                         "법정동": "창신동",
#                         "법정동본번코드": "0601",
#                         "법정동부번코드": "0005",
#                         "법정동시군구코드": "11110",
#                         "법정동읍면동코드": "17400",
#                         "법정동지번코드": "1",
#                         "아파트": "MID그린(4동)",
#                         "월": "12",
#                         "일": "20",
#                         "일련번호": "11110-97",
#                         "전용면적": "59.55",
#                         "지번": "601-5",
#                         "지역코드": "11110",
#                         "층": "7"
#                     },
#                     {
#                         "거래금액": "78,700",
#                         "건축년도": "2009",
#                         "년": "2018",
#                         "도로명": "숭인동길",
#                         "도로명건물본번호코드": "00021",
#                         "도로명건물부번호코드": "00000",
#                         "도로명시군구코드": "11110",
#                         "도로명일련번호코드": "01",
#                         "도로명지상지하코드": "0",
#                         "도로명코드": "4100204",
#                         "법정동": "숭인동",
#                         "법정동본번코드": "0766",
#                         "법정동부번코드": "0000",
#                         "법정동시군구코드": "11110",
#                         "법정동읍면동코드": "17500",
#                         "법정동지번코드": "1",
#                         "아파트": "종로청계힐스테이트",
#                         "월": "12",
#                         "일": "21",
#                         "일련번호": "11110-2234",
#                         "전용면적": "84.9478",
#                         "지번": "766",
#                         "지역코드": "11110",
#                         "층": "9"
#                     },
#                     {
#                         "거래금액": "65,000",
#                         "건축년도": "2009",
#                         "년": "2018",
#                         "도로명": "숭인동길",
#                         "도로명건물본번호코드": "00021",
#                         "도로명건물부번호코드": "00000",
#                         "도로명시군구코드": "11110",
#                         "도로명일련번호코드": "01",
#                         "도로명지상지하코드": "0",
#                         "도로명코드": "4100204",
#                         "법정동": "숭인동",
#                         "법정동본번코드": "0766",
#                         "법정동부번코드": "0000",
#                         "법정동시군구코드": "11110",
#                         "법정동읍면동코드": "17500",
#                         "법정동지번코드": "1",
#                         "아파트": "종로청계힐스테이트",
#                         "월": "12",
#                         "일": "26",
#                         "일련번호": "11110-2234",
#                         "전용면적": "59.9426",
#                         "지번": "766",
#                         "지역코드": "11110",
#                         "층": "2"
#                     },
#                     {
#                         "거래금액": "24,300",
#                         "건축년도": "1997",
#                         "년": "2018",
#                         "도로명": "숭인동1길",
#                         "도로명건물본번호코드": "00031",
#                         "도로명건물부번호코드": "00000",
#                         "도로명시군구코드": "11110",
#                         "도로명일련번호코드": "01",
#                         "도로명지상지하코드": "0",
#                         "도로명코드": "4100200",
#                         "법정동": "숭인동",
#                         "법정동본번코드": "0181",
#                         "법정동부번코드": "0121",
#                         "법정동시군구코드": "11110",
#                         "법정동읍면동코드": "17500",
#                         "법정동지번코드": "1",
#                         "아파트": "도시그린빌라",
#                         "월": "12",
#                         "일": "29",
#                         "일련번호": "11110-44",
#                         "전용면적": "57.45",
#                         "지번": "181-121",
#                         "지역코드": "11110",
#                         "층": "3"
#                     },
#                     {
#                         "거래금액": "90,000",
#                         "건축년도": "2003",
#                         "년": "2018",
#                         "도로명": "평창24길",
#                         "도로명건물본번호코드": "00006",
#                         "도로명건물부번호코드": "00000",
#                         "도로명시군구코드": "11110",
#                         "도로명일련번호코드": "01",
#                         "도로명지상지하코드": "0",
#                         "도로명코드": "4100499",
#                         "법정동": "평창동",
#                         "법정동본번코드": "0046",
#                         "법정동부번코드": "0001",
#                         "법정동시군구코드": "11110",
#                         "법정동읍면동코드": "18300",
#                         "법정동지번코드": "1",
#                         "아파트": "크래스빌",
#                         "월": "12",
#                         "일": "15",
#                         "일련번호": "11110-101",
#                         "전용면적": "187.9",
#                         "지번": "46-1",
#                         "지역코드": "11110",
#                         "층": "4"
#                     },
#                     {
#                         "거래금액": "135,500",
#                         "건축년도": "2009",
#                         "년": "2018",
#                         "도로명": "평창문화로",
#                         "도로명건물본번호코드": "00156",
#                         "도로명건물부번호코드": "00000",
#                         "도로명시군구코드": "11110",
#                         "도로명일련번호코드": "01",
#                         "도로명지상지하코드": "0",
#                         "도로명코드": "3100023",
#                         "법정동": "평창동",
#                         "법정동본번코드": "0108",
#                         "법정동부번코드": "0000",
#                         "법정동시군구코드": "11110",
#                         "법정동읍면동코드": "18300",
#                         "법정동지번코드": "1",
#                         "아파트": "롯데캐슬 로잔",
#                         "월": "12",
#                         "일": "15",
#                         "일련번호": "11110-2246",
#                         "전용면적": "190.743",
#                         "지번": "108",
#                         "지역코드": "11110",
#                         "층": "4"
#                     },
#                     {
#                         "거래금액": "41,500",
#                         "건축년도": "2004",
#                         "년": "2018",
#                         "도로명": "평창12길",
#                         "도로명건물본번호코드": "00014",
#                         "도로명건물부번호코드": "00004",
#                         "도로명시군구코드": "11110",
#                         "도로명일련번호코드": "01",
#                         "도로명지상지하코드": "0",
#                         "도로명코드": "4100488",
#                         "법정동": "평창동",
#                         "법정동본번코드": "0179",
#                         "법정동부번코드": "0005",
#                         "법정동시군구코드": "11110",
#                         "법정동읍면동코드": "18300",
#                         "법정동지번코드": "1",
#                         "아파트": "밀레니엄",
#                         "월": "12",
#                         "일": "20",
#                         "일련번호": "11110-2292",
#                         "전용면적": "110.61",
#                         "지번": "179-5",
#                         "지역코드": "11110",
#                         "층": "2"
#                     }
#                 ]
#             },
#             "numOfRows": "10",
#             "pageNo": "1",
#             "totalCount": "11"
#         }
#     }
# }
# [거래금액]78,700 [아파트명] 종로청계힐스테이트 [전용면적]84.9478
# [거래금액]90,000 [아파트명] 크래스빌 [전용면적]187.9
# [거래금액]135,500 [아파트명] 롯데캐슬 로잔 [전용면적]190.743
# [거래금액]41,500 [아파트명] 밀레니엄 [전용면적]110.61
